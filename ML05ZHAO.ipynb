# %%
# Assignment due week 5 by Qizhi Zhao

# %%
from sklearn import __version__ as sklearn_version
from distutils.version import LooseVersion
from IPython.display import Image 
from sklearn import datasets
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

iris = datasets.load_iris()

# %%
# CASE 01 sepal length vs sepal width------------------------------------------
X = iris.data[:, [0, 1]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('sepal length [standardized]')
plt.ylabel('sepal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print('Aeccurracy of')
print('CASE 01 sepal length vs sepal width',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 01 sepal length vs sepal width 0.826666666667

# %%
# CASE 02 sepal length vs petal length-------------------------------------
X = iris.data[:, [0, 2]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('sepal length [standardized]')
plt.ylabel('petal length [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print('Aeccurracy of')
print('CASE 02 sepal length vs petal length',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 02 sepal length vs petal length 0.946666666667

# %%
# CASE 03 sepal length vs petal width
X = iris.data[:, [0, 3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('sepal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print('Aeccurracy of')
print('CASE 03 sepal length vs petal width',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 03 sepal length vs petal width 0.94

# %%
# CASE 04 sepal width vs petal length
X = iris.data[:, [1, 2]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('sepal width [standardized]')
plt.ylabel('petal length [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print('Aeccurracy of')
print('CASE 04 sepal width vs petal length',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 04 sepal width vs petal length 0.94

# %%
# CASE 05 sepal width vs petal width
X = iris.data[:, [1, 3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('sepal width [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print('Aeccurracy of')
print('CASE 05 sepal width vs petal width' ,lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 05 sepal width vs petal width 0.96

# %%
# CASE 06 petal length vs petal width
X = iris.data[:, [2, 3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)


sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

lr = LogisticRegression(C=100.0, random_state=1)
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
print('Aeccurracy of')
print('CASE 06 petal length vs petal width',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 06 petal length vs petal width 0.96

# %%
# CASE 07 sepal length vs sepal width vs petal length
X = iris.data[:, [0,1,2]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y,  test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
lr = LogisticRegression(C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('Aeccurracy of')
print('CASE 07 sepal length vs sepal width vs petal length',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 07 sepal length vs sepal width vs petal length 0.953333333333

# %%
# CASE 08 sepal length vs sepal width vs petal width
X = iris.data[:, [0,1,3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y,  test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
lr = LogisticRegression(C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('Aeccurracy of')
print('CASE 08 sepal length vs sepal width vs petal width',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 08 sepal length vs sepal width vs petal width 0.953333333333

# %%
# CASE 09 sepal length vs petal length vs petal width
X = iris.data[:, [0,2,3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y,  test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
lr = LogisticRegression(C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('Aeccurracy of')
print(' CASE 09 sepal length vs petal length vs petal width' ,lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
#  CASE 09 sepal length vs petal length vs petal width 0.96

# %%
# CASE 10 sepal width vs petal length vs petal width
X = iris.data[:, [1,2,3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y,  test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
lr = LogisticRegression(C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('Aeccurracy of')
print('CASE 10 sepal width vs petal length vs petal width',lr.score(X_combined_std, y_combined))
# Out:
# Aeccurracy of
# CASE 10 sepal width vs petal length vs petal width 0.96

# %%
# CASE 11 sepal length vs sepal width vs petal length vs petal width
X = iris.data[:, [0,1,2,3]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y,  test_size=0.3, random_state=1, stratify=y)
#print (X_train, X_test, y_train, y_test)

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
lr = LogisticRegression(C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('All feature case')
print('No regularization')
print('train data accurracy: ',lr.score(X_train, y_train))
print('test data accurracy: ',lr.score(X_test, y_test))
print('combined data accurracy: ',lr.score(X_combined_std, y_combined))

lr = LogisticRegression(penalty='l1',C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('L1 regularization')
print('train data accurracy: ',lr.score(X_train, y_train))
print('test data accurracy: ',lr.score(X_test, y_test))
print('combined data accurracy: ',lr.score(X_combined_std, y_combined))
lr = LogisticRegression(penalty='l2',C=1000.0, random_state=0)
lr.fit(X_train_std, y_train)
print('L2 regularization')
print('train data accurracy: ',lr.score(X_train, y_train))
print('test data accurracy: ',lr.score(X_test, y_test))
print('combined data accurracy: ',lr.score(X_combined_std, y_combined))
# Out:
# All feature case
# No regularization
# train data accurracy:  0.333333333333
# test data accurracy:  0.333333333333
# combined data accurracy:  0.953333333333
# L1 regularization
# train data accurracy:  0.333333333333
# test data accurracy:  0.333333333333
# combined data accurracy:  0.96
# L2 regularization
# train data accurracy:  0.333333333333
# test data accurracy:  0.333333333333
# combined data accurracy:  0.953333333333

# %%
# The following cases have the highest combined data accurracy of 0.96
# CASE 05 sepal width vs petal width 
# CASE 06 petal length vs petal width
# CASE 09 sepal length vs petal length vs petal width
# CASE 10 sepal width vs petal length vs petal width 0.96
# CASE 11 All feature with L1 regularization


# There are some low accuracy cases for 2-features but there isnt for 3 and 4 features
# so, more dimension helps the accuracy of the regression
# and for the last case of all feature
# no-regularization and L2 regularization have same accuracy of 95.333
# But there is L1 regularization which improve the accuracy by little. 
# I think that It is not neccessary but it could be used to help for accuracy .
